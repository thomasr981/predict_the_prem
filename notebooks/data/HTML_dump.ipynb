# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

from IPython.display import Javascript, display, clear_output, HTML

display(HTML("<style>.container { width:100% !important;}</style>"))

import pandas as pd

pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

# %%
HTML("""
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <title>Click Row to Toggle</title>
  <style>
    table {
      border-collapse: collapse;
      width: 60%;
      margin: 20px auto;
    }

    td, th {
      border: 1px solid #ccc;
      padding: 10px;
    }

    .clickable {
      cursor: pointer;
      background-color: #f0e6f7;
    }

    .hidden-row {
      display: none;
    }

    .details {
      background-color: #f9f3fc;
    }
  </style>
</head>
<body>

  <table>
    <tr class="clickable" onclick="toggleRow('details1')">
      <td>Alice</td>
      <td>88</td>
    </tr>
    <tr id="details1" class="hidden-row details">
      <td colspan="2">Details about Alice's performance...</td>
    </tr>

    <tr class="clickable" onclick="toggleRow('details2')">
      <td>Bob</td>
      <td>75</td>
    </tr>
    <tr id="details2" class="hidden-row details">
      <td colspan="2">Bob missed a quiz but performed well overall.</td>
    </tr>
  </table>

  <script>
    function toggleRow(rowId) {
      const row = document.getElementById(rowId);
      row.classList.toggle("hidden-row");
    }
  </script>

</body>
</html>
""")
